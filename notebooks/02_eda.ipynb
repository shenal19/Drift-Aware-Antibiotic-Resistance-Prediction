# %% [markdown]
# # 02 - Exploratory Data Analysis (Phase 2)
# **E. coli -> Levofloxacin.** Four figures, each tied to the research question
# (temporal reliability of a resistance model). No modelling here. Logic lives in
# `src/eda.py`; this notebook drives it and displays the outputs inline.

# %%
import sys; sys.path.insert(0, '..')
from src import eda
d, s = eda.run()   # computes summaries + writes reports/figures/*.png
print('rows:', len(d), '| resistant rate: {:.1%}'.format(d['target'].mean()))

# %% [markdown]
# ## Summary tables

# %%
s['per_year'][['n','resist_rate']]

# %%
s['by_age']

# %%
s['by_country']

# %% [markdown]
# ## Figures
# 1. class balance 2. resistance % by year (95% CI) + count/year 3. resistance by subgroup 4. input-distribution shift over years

# %% [markdown]
# ![class_balance](../reports/figures/class_balance.png)

# %% [markdown]
# ![temporal_resistance](../reports/figures/temporal_resistance.png)

# %% [markdown]
# ![resistance_by_subgroup](../reports/figures/resistance_by_subgroup.png)

# %% [markdown]
# ![input_shift_over_time](../reports/figures/input_shift_over_time.png)
