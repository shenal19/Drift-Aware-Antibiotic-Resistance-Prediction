# %% [markdown]
# # 08 - Risk Estimation (Phase 8)
# **E. coli -> Levofloxacin.** An interpretation layer over the **Phase-7 calibrated** probability: Low (<0.30), Moderate (0.30-<0.60), High (>=0.60). No model is loaded or trained. Bands are **heuristic research categories, not clinical thresholds**; the continuous probability is always kept. Logic in `src/risk_estimation.py`.

# %%
import sys; sys.path.insert(0,'..')
from src import risk_estimation as R
df, dist, byyear, cal, checks = R.run(save=True)
checks

# %% [markdown]
# ## Overall risk distribution

# %%
dist

# %% [markdown]
# ## Risk distribution by year

# %%
byyear

# %% [markdown]
# ## Predicted vs observed by band (descriptive separation)

# %%
cal

# %% [markdown]
# ## Boundary behaviour test

# %%
R._boundary_tests()[0]

# %% [markdown]
# ## Figures

# %% [markdown]
# ![risk_band_distribution](../reports/figures/risk_band_distribution.png)

# %% [markdown]
# ![risk_band_by_year](../reports/figures/risk_band_by_year.png)

# %% [markdown]
# ![risk_band_predicted_vs_observed](../reports/figures/risk_band_predicted_vs_observed.png)

# %% [markdown]
# ![probability_with_risk_boundaries](../reports/figures/probability_with_risk_boundaries.png)
